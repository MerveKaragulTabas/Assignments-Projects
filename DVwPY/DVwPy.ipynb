# %% [markdown]
# <a href="https://colab.research.google.com/github/MerveKaragulTabas/DVWPY/blob/main/DVwPy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Basic Library
import numpy as np
import pandas as pd
# Libraries for Visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings;
warnings.filterwarnings('ignore')

# %%
age = [25, 27, 29, 31, 33, 35, 37, 39, 41, 43, 45]
salary = [38496, 42000, 46752, 49320, 53200,
         56000, 62316, 64928, 67317, 68748, 73752]
salary_2 = [45372, 48876, 53850, 57287, 63016,
            65998, 70003, 70000, 71496, 75370, 83640]

# %%
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),fontsize=18, ha='center')
    plt.title(i)
plt.suptitle("with for loop")
plt.tight_layout()
plt.show()

# %%
x= np.array([15,17,18,17,12,17,12,19,14,11,12,19,16,13])
y= np.array([99,86,87,88,81,86,93,87,94,78,77,85,86,85])

# %%
plt.scatter(x,y)
plt.show()

# %%
y = np.random.randint(10,100,50)
x = np.random.randint(10,100,50)
plt.scatter(x,y)
plt.show()

# %%
sns.get_dataset_names()     #datasetlerini çağırma.
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
plt.scatter(tips["tip"], tips["total_bill"]);

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23,17,35,29,12]

# %%
fig, ax = plt.subplots()
ax.bar(langs, students)
# Out:
# <BarContainer object of 5 artists>

# %%
fig, ax = plt.subplots()
ax.barh(langs, students)     #yanal çizgiler istiyorsak bar sonuna h eklemeiz gerekir.
# Out:
# <BarContainer object of 5 artists>

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# günlere göre total-bill

# %%
tips.groupby("day").sum()
# Out:
#       total_bill     tip  size
# day
# Thur     1096.33  171.83   152
# Fri       325.88   51.96    40
# Sat      1778.40  260.40   219
# Sun      1627.16  247.39   216

# %%
day =tips.groupby("day").sum().index
day
# Out:
# CategoricalIndex(['Thur', 'Fri', 'Sat', 'Sun'], categories=['Thur', 'Fri', 'Sat', 'Sun'], ordered=False, name='day', dtype='category')

# %%
tips.day.unique()
# Out:
# ['Sun', 'Sat', 'Thur', 'Fri']
# Categories (4, object): ['Sun', 'Sat', 'Thur', 'Fri']

# %%
day_of_total_bill= list(tips.groupby("day")["total_bill"].sum())
day_of_total_bill
# Out:
# [1096.3299999999997,
#  325.87999999999994,
#  1778.3999999999996,
#  1627.1600000000003]

# %%
fig, ax = plt.subplots()
ax.bar(day, day_of_total_bill)
plt.show()

# %%
fig, ax = plt.subplots()
ax.barh(day, day_of_total_bill)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,7))
ax.bar(day, day_of_total_bill)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12,7))
ax.barh(day, day_of_total_bill)
plt.show()

# %%
day_of_tip= list(tips.groupby("day")["tip"].sum())
day_of_tip
# Out:
# [171.83, 51.96, 260.4, 247.39000000000007]

# %%
fig, ax = plt.subplots()
ax.bar(day, day_of_tip)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
ax.bar(day, day_of_total_bill,  label="total_bill")
ax.bar(day, day_of_tip, label="tip")
plt.legend()

# %%
# Optional hard to coding
fig, ax = plt.subplots(figsize=(10,5))
p = np.arange(len(day))
width = 0.15
ax.bar(p - width/2, day_of_total_bill, width, label="total_bill")
ax.bar(p + width/2, day_of_tip, width, label="tip")
ax.set_xticks(p)
ax.set_xticklabels(day)
plt.legend()
plt.show()

# %%
# Optional hard to coding
fig, ax = plt.subplots(figsize=(10,5))
p = np.arange(len(day))
width = 0.4
ax.bar(p - width/2, day_of_total_bill, width, label="total_bill")
ax.bar(p + width/2, day_of_tip, width, label="tip")
ax.set_xticks(p)
ax.set_xticklabels(day)
plt.legend()
plt.show()

# %%
np.random.randn(250)
# Out:
# array([ 1.72739459, -1.92116215,  1.21816002, -0.42732   ,  0.63674989,
#        -1.63215832, -1.65393234,  1.1458159 ,  0.56595961,  0.64603513,
#         0.90514173, -0.62892225,  0.39764407,  0.48920288,  1.45101115,
#         0.60975659, -0.27145076, -0.15687591, -1.76616163,  0.98558271,
#         0.93332003,  0.60500437, -0.15185313, -0.81854117,  1.21659968,
#        -1.43872148, -0.31307156, -0.03289922, -0.68155336,  1.57557907,
#         1.06375779,  0.28207305,  0.11747019,  0.91764691,  0.66378727,
#        -0.7777784 , -0.66340039,  0.34538212,  0.28717472, -0.67421582,
#         1.29410858,  1.43797861,  0.07297215,  0.16280577,  1.40596811,
#         0.83665313, -1.74896443, -1.12123258,  0.73414417, -1.13613573,
#         0.63413044, -0.26444877,  2.57113902, -1.62999558,  0.49436335,
#        -1.07137085, -2.26810297, -1.17325872,  0.63541199, -0.44947053,
#        -2.03094468, -0.79290713, -0.12315079,  1.12898581, -0.28285639,
# ...

# %%
x = np.random.randn(250)
plt.hist(x)
plt.show()

# %%
plt.hist(x ,bins=30)
plt.show()

# %%
tips.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips["total_bill"]
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
plt.hist(tips["total_bill"])
plt.show()

# %%
plt.hist(tips["total_bill"], bins = 40)
plt.show()

# %%
plt.hist(tips.tip, bins = 40)
plt.show()

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
X = np.random.normal(170,10,250)
plt.boxplot(X)
plt.show()

# %%
X = np.random.normal(170,10,250)
plt.boxplot(X, vert = False)     # vert = false yan dönderme yaptı.
plt.show()

# %%
box = np.array(np.random.rand(10,4))
box
# Out:
# array([[0.40341786, 0.94729367, 0.01234818, 0.61131874],
#        [0.96497562, 0.73900888, 0.74380525, 0.94918256],
#        [0.95525686, 0.93630887, 0.1228943 , 0.42196298],
#        [0.91328241, 0.13380081, 0.61032254, 0.35134157],
#        [0.15611225, 0.85101782, 0.72035826, 0.66649701],
#        [0.21513593, 0.44009866, 0.9564375 , 0.28635093],
#        [0.33610825, 0.21180821, 0.24282637, 0.5297907 ],
#        [0.59692839, 0.47713778, 0.1768893 , 0.95486966],
#        [0.54391209, 0.54969494, 0.80710924, 0.11001735],
#        [0.36236853, 0.71260763, 0.23150431, 0.00389012]])

# %%
plt.boxplot(box, vert=False)
plt.show()

# %%
plt.boxplot(box, labels=['A', 'B', 'C', 'D'])
plt.show()

# %%
plt.boxplot(box, labels=['A', 'B', 'C', 'D'], vert = False)
plt.show()

# %%
plt.boxplot(tips["total_bill"], vert=False)
plt.show()

# %%
plt.boxplot(tips["tip"], vert=False)
plt.show()

# %%
plt.boxplot([tips.tip, tips.total_bill])
plt.show()

# %%
tips.head(2)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3

# %%
tips.iloc[:,0:2]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %%
plt.boxplot(tips.iloc[:,0:2],labels=['total_bill', 'tip'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-b8b7827aa3fd> in <module>()
# ----> 1 plt.boxplot(tips.iloc[:,0:2],labels=['total_bill', 'tip'])
#       2 plt.show()
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, data)
#    2446         whiskerprops=whiskerprops, manage_ticks=manage_ticks,
#    2447         autorange=autorange, zorder=zorder, **({"data": data} if data
# -> 2448         is not None else {}))
#    2449
#    2450
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/deprecation.py in wrapper(*args, **kwargs)
# ...

# %%
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

# %%
plt.pie(y, labels=mylabels)
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels=mylabels)
plt.show()

# %%
plt.pie(y, labels=mylabels, autopct="%.1f")
plt.show()

# %%
plt.pie(y, labels=mylabels, labeldistance= 0.7, autopct="%.1f")  # yazıları içeriye labeldistance ile içeri aldık.
plt.show()

# %%
plt.figure(figsize=(10,8))
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.1, 0, 0, 0]

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, explode=myexplode, labeldistance = 0.7, autopct="%.2f")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0, 0.2, 0, 0]

# %%
plt.figure(figsize=(10,8))
plt.pie(y, labels = mylabels, explode=myexplode, labeldistance = 0.7, autopct="%.2f")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink']
explode_list = [0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.
y = np.array([25, 35, 25, 15])
mylabels = ["Bananas", "Apples", "Cherries", "Dates"]
myexplode = [0.1, 0, 0, 0]
plt.pie(y, labels = mylabels,labeldistance=0.7, autopct="%.1f", startangle=90, shadow=True, pctdistance=1.1, colors=colors_list, explode=explode_list)
plt.legend()
plt.show()

# %%
# autopct = sayıların .dan sonraki sayısı(float basamak)
# startangle = kaç derece döndürüleceği
# pctdistance= sayıların ne kadar mesafeye yazılacağı
# explode = merkezden uzaklaşan pasta dilimleri
# labeldistance = birimlerin merkezden uzaklığı, "0" merkez, 1 çember

# %%
# Basic Libraries
import pandas as pd
import numpy as np
import scipy
# Libraries for visualizaton
import matplotlib.pyplot as plt
import seaborn as sns
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
plt.figure(figsize=(12,8))
ax = sns.scatterplot(x='total_bill',y='tip',data=tips)
ax.set(xlabel='Total Bill', ylabel='Tip', title='Some title')
#plt.legend(labels=['legend1'])
plt.show()

# %%
## HUE komutu kategorık verıyı sınıflandırıyor. hue = groupby

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,hue="sex", s=200)

# %%
## STYLE

# %%
sns.scatterplot(x="total_bill",y="tip",data=tips,hue="sex", s=200, style="sex");

# %%
sns.scatterplot(x='total_bill',y='tip',size="sex", data=tips);

# %%
sns.scatterplot(x='total_bill',y='tip',s=200, data=tips, alpha=1);
#sns.scatterplot(x='salary',y='sales',data=df,s=200,linewidth=0,alpha=0.2)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='total_bill',y='tip', data=tips,style='sex',hue='sex',s=100)
# Call savefig in the same cell
plt.savefig('example_scatter.jpg')

# %%
sns.rugplot(x='total_bill', data=tips, height=0.5)
# height : number
sns.rugplot(x='total_bill', data=tips, height=0.5)
# height : number
#     Proportion of axes extent covered by each rug element.

# %%
sns.displot(x='total_bill', data=tips, kde=True)

# %%
sns.histplot(data = tips, x = 'total_bill')

# %%
sns.histplot(data = tips, x = 'total_bill', bins = 30, kde= True)

# %%
sns.set(style='darkgrid')
sns.histplot(data = tips, x = 'total_bill',bins=20)

# %%
sns.displot(data = tips, x = 'total_bill',bins=20,kde=False,
            color='red',edgecolor='black',lw=4,ls='--')

# %%
sns.set(style='darkgrid', rc={"grid.color": ".6", "grid.linestyle": ":"})
sns.histplot(data = tips, x = 'total_bill',bins=20);

# %%
# color = renk,
# edgecolor = kenarlık,
# lw= kenarlık kalınlığı,
# ls= kenarlık şekli

# %%
sns.kdeplot(data = tips, x = 'total_bill')

# %%
sns.kdeplot(x = "total_bill", data = tips, bw_adjust = 0.2, shade = True, color = "red");

# %%
data = pd.DataFrame(np.random.normal(0,1,size=(100,2)),columns=['x','y'])
data
# Out:
#            x         y
# 0   0.924565  0.215604
# 1   0.289012 -0.723069
# 2  -0.128347 -1.335391
# 3   0.523971 -0.576495
# 4   0.522430 -0.363720
# ..       ...       ...
# 95  0.244472  2.556524
# 96 -0.549548 -1.154000
# 97  0.439315  0.045389
# 98  0.012079  1.395393
# 99  0.970291  0.465837
#
# [100 rows x 2 columns]

# %%
sns.kdeplot(data = data, x = "x", y = "y")
